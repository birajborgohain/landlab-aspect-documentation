# %%
def greet():
    print("Hello")

x = greet()
greet()

print(x)
# Out:
# Hello
# Hello
# None

# %%
def greet():
    # pass
    return
    # print()

# x = greet()

greet()

# print(x)

# %%
def greet():
    print("Start")
    pass
    print("End")

greet()
# Out:
# Start
# End
